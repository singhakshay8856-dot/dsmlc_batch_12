# %% [markdown]
# <a href="https://colab.research.google.com/github/singhakshay8856-dot/dsmlc_batch_12/blob/main/dsml_12_day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = "hello"

# %%
type(data)
# Out:
# str

# %%
data1 ="Hello"

# %%
type(data1)
# Out:
# str

# %%
data = "hello"
data1 = 'hello'

# %%
type(data)
# Out:
# str

# %%
type(data1)
# Out:
# str

# %%
data = "python"

# %%
data[0]
# Out:
# 'p'

# %%
data[-6]
# Out:
# 'p'

# %%
data[5]
# Out:
# 'n'

# %%
data[-1]
# Out:
# 'n'

# %%
data = "this is a Ram's car"
data
# Out:
# "this is a Ram's car"

# %%
data = 'this is a "boy"'
data
# Out:
# 'this is a "boy"'
